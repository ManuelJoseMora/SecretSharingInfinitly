# %%
import shamirs

# %%
key = input("Por favor, introduce la clave como un número entero positivo:\n")
# Out:
# Por favor, introduce la clave como un número entero positivo:
# 2142356235

# %%
# Comprobamos que la clave sea un numero entero posotivo
try:
    if int(key) > 0:
        print("Seguimos...")
    else:    
        print("La clave debe ser un entero positivo. Vuelve a empezar.")
        
except:
    print("La clave debe ser un entero positivo. Vuelve a empezar y prueba de nuevo.")
# Out:
# Seguimos...

# %%
# Se introducen el k threhsold del esquema
k = input("Ahora introduce el k-threshold como un numeor entero positivo:\n")
# Out:
# Ahora introduce el k-threshold como un numeor entero positivo:
# 3

# %%
# Comprobamos que el threshold k es un numero positivo
try:
    if int(k) > 0:
        print("Seguimos...")
    else:    
        print("El threshold debe ser un entero positivo. Vuelve a empezar.")
        
except:
    print("El threshold debe ser un entero positivo. Vuelve a empezar y prueba de nuevo.")
# Out:
# Seguimos...

# %%
participants = []
lista_desencryptar = []
seguimos = True

while (seguimos):
    
    participant = input("""
    **************************************************
     Por favor, elige una opción para continuar:\n
     1 - Añadir un nuevo Participante. \n
     2 - Pasar un lista de participantes para tratar de desencriptar la clave.\n 
     3 - Finalizar. \n
    **************************************************\n\n""")
    
    
    if participant == '1':
        nombre_participante = input("Introduce el nombre del nuevo participante.\n\n")
        if nombre_participante not in participants:
            participants.append(nombre_participante)
            print("Muy bien, seguimos...\n")
        else:
            print("Ese participante ya ha sido incluido.\n")
        
    elif participant == '2':
        input_lista = input("Introduce una lista con los nombres de los partipantes separados por una coma.\n\n")
        lista_desencryptar = [ s for s in input_lista.split(",") ]
    elif participant == '3':
        seguimos = False        
    else:
        print("Las opciones son 1, 2 ó 3. Vuelve a empezar.")
        seguimos = False
# Out:
#     **************************************************
#      Por favor, elige una opción para continuar:
#
#      1 - Añadir un nuevo Participante.
#
#      2 - Pasar un lista de participantes para tratar de desencriptar la clave.
#
#      3 - Finalizar.
#
#     **************************************************
#
# 3

# %%
# Cargamos participantes de manera manual para K = 3, 2 generaciones
participants = ['Pedro', 'Manuel', 'Maria', 'Luis', 'Ana', 'Rocio', 'Kevin', 'Jorge', 'Mario', 'Guillermo', 'Sara', 'Rebeca']

# %%
# Cargamos participantes de manera manual para K = 2, 2 generaciones
participants = ['Pedro', 'Manuel', 'Maria', 'Luis', 'Ana', 'Rocio']

# %%
# Cargamos participantes de manera manual para K = 2, 3 generaciones
participants = ['Pedro', 'Manuel', 'Maria', 'Luis', 'Ana', 'Rocio', 'Kevin', 'Jorge', 'Mario', 'Guillermo', 'Sara', 'Rebeca']

# %%
k = 3

# %% [markdown]
# _Ya tenemos una lista con los participantes, otra con los candidatos a desencriptar, la clave y el k threshold._

# %% [markdown]
# __Gestion de las Generaciones__

# %%
n_participantes = len(participants)
n_candidatos = len(lista_desencryptar)

# %%
def generation_size( i, k):
    size_g_i = i*(2**(k-1))
    return size_g_i

# %%
def participant_idx(participant_name, participants):
    participant_index = participants.index(participant_name)
    return participant_index

# %%
def participant_generation(participant_name):
    idx = participant_idx(participant_name, participants)
    init = 1
    generation_size_value_limit = generation_size(init, int(k)) - 1
    while idx > generation_size_value_limit:
        
        init = init +1
        generation_size_value_limit = generation_size_value_limit + (generation_size(init, int(k)) - 1)
        
    return init

# %%
# Cargamos las lista de los shares en listas para cada Particnant. 
# Primero, en el primer nivel (index 0 de la lista) de cada Participante el share correspondiente a su generación.
# En el resto de niveles de cada partipante estan los shares compartidos entre generaciones:
#     nivel 1 --> Share(s_1, size(g), threshold = 1)
#     nivel 1 --> Share(s_2, size(g), threshold = 2)
#     ...
#     nivel 1 --> Share(s_k-1, size(g), threshold = k-1)

# %%
# ------------------------------------------------------
# Caso 1 - Dentro de una misma generación.
# ------------------------------------------------------
# Hay que ejecutar Shamir para cada generación.
# Y cada Partipante tendrá aociada una lista donde en la 
# primera posicicón tendra el share de su generación que
# le corresponda.
# ------------------------------------------------------

n = 1
n_generacion = 1
Fin = True
while (Fin):
    while (n <= n_participantes):
        size_g = generation_size(int(n_generacion), int(k))
        sss = shamirs.shares(int(key), quantity= int(size_g), threshold=int(k))
        n_shares = 0
        print(sss)
        print("\n")
        idx_g = 1
        while (idx_g <= size_g):
            idx_participant = n-1
            participant_i = participants[idx_participant]
            print("- Generación: " + str(n_generacion))
            print("- Size of g: " + str(size_g))
            print("- Participante: " + str(participant_i))
            print(" -Share: " +  str(sss[n_shares]))
            globals()[participant_i] = [sss[n_shares]]
            
            
            n_shares = n_shares + 1
            n = n + 1
            idx_g = idx_g + 1
            
        n_generacion = n_generacion + 1
    Fin = False
# Out:
# [share(1, 126389823754348948066896313035488939980, 170141183460469231731687303715884105727), share(2, 82638464048228664402105322352951417998, 170141183460469231731687303715884105727), share(3, 38887104342108380737314331670413896016, 170141183460469231731687303715884105727), share(4, 165276928096457328804210644703760479761, 170141183460469231731687303715884105727)]
#
#
# - Generación: 1
# - Size of g: 4
# - Participante: Pedro
#  -Share: share(1, 126389823754348948066896313035488939980, 170141183460469231731687303715884105727)
# - Generación: 1
# - Size of g: 4
# - Participante: Manuel
#  -Share: share(2, 82638464048228664402105322352951417998, 170141183460469231731687303715884105727)
# - Generación: 1
# - Size of g: 4
# - Participante: Maria
#  -Share: share(3, 38887104342108380737314331670413896016, 170141183460469231731687303715884105727)
# - Generación: 1
# - Size of g: 4
# - Participante: Luis
#  -Share: share(4, 165276928096457328804210644703760479761, 170141183460469231731687303715884105727)
# [share(1, 70301567886194670075071481416772557598, 170141183460469231731687303715884105727), share(2, 140603135772389340150142962831402758961, 170141183460469231731687303715884105727), share(3, 40763520198114778493527140530148854597, 170141183460469231731687303715884105727), share(4, 111065088084309448568598621944779055960, 170141183460469231731687303715884105727), share(5, 11225472510034886911982799643525151596, 170141183460469231731687303715884105727), share(6, 81527040396229556987054281058155352959, 170141183460469231731687303715884105727), share(7, 151828608282424227062125762472785554322, 170141183460469231731687303715884105727), share(8, 51988992708149665405509940171531649958, 170141183460469231731687303715884105727)]
#
#
# - Generación: 2
# - Size of g: 8
# - Participante: Ana
#  -Share: share(1, 70301567886194670075071481416772557598, 170141183460469231731687303715884105727)
# - Generación: 2
# - Size of g: 8
# - Participante: Rocio
#  -Share: share(2, 140603135772389340150142962831402758961, 170141183460469231731687303715884105727)
# - Generación: 2
# - Size of g: 8
# - Participante: Kevin
#  -Share: share(3, 40763520198114778493527140530148854597, 170141183460469231731687303715884105727)
# - Generación: 2
# - Size of g: 8
# - Participante: Jorge
#  -Share: share(4, 111065088084309448568598621944779055960, 170141183460469231731687303715884105727)
# - Generación: 2
# - Size of g: 8
# - Participante: Mario
#  -Share: share(5, 11225472510034886911982799643525151596, 170141183460469231731687303715884105727)
# - Generación: 2
# - Size of g: 8
# - Participante: Guillermo
#  -Share: share(6, 81527040396229556987054281058155352959, 170141183460469231731687303715884105727)
# - Generación: 2
# - Size of g: 8
# - Participante: Sara
#  -Share: share(7, 151828608282424227062125762472785554322, 170141183460469231731687303715884105727)
# - Generación: 2
# - Size of g: 8
# - Participante: Rebeca
#  -Share: share(8, 51988992708149665405509940171531649958, 170141183460469231731687303715884105727)

# %%
for participant in participants:
    print(participant)
    print(globals()[participant])
# Out:
# Pedro
# [share(1, 126389823754348948066896313035488939980, 170141183460469231731687303715884105727)]
# Manuel
# [share(2, 82638464048228664402105322352951417998, 170141183460469231731687303715884105727)]
# Maria
# [share(3, 38887104342108380737314331670413896016, 170141183460469231731687303715884105727)]
# Luis
# [share(4, 165276928096457328804210644703760479761, 170141183460469231731687303715884105727)]
# Ana
# [share(1, 70301567886194670075071481416772557598, 170141183460469231731687303715884105727)]
# Rocio
# [share(2, 140603135772389340150142962831402758961, 170141183460469231731687303715884105727)]
# Kevin
# [share(3, 40763520198114778493527140530148854597, 170141183460469231731687303715884105727)]
# Jorge
# [share(4, 111065088084309448568598621944779055960, 170141183460469231731687303715884105727)]
# Mario
# [share(5, 11225472510034886911982799643525151596, 170141183460469231731687303715884105727)]
# Guillermo
# [share(6, 81527040396229556987054281058155352959, 170141183460469231731687303715884105727)]
# Sara
# [share(7, 151828608282424227062125762472785554322, 170141183460469231731687303715884105727)]
# Rebeca
# [share(8, 51988992708149665405509940171531649958, 170141183460469231731687303715884105727)]

# %%
# ------------------------------------------------------
# Caso 2 - Entre diferentes Generaciones.
# ------------------------------------------------------
# Hay que generar (s_1, ...., s_k-1) shares para cada 
# generación g y compartir s_i con SSS(i,size(g))
# ------------------------------------------------------

# Generamos (k-1)*numero_generaciones shares
numero_generaciones = n_generacion - 1
numero_shares = numero_generaciones*(int(k)-1)
sss_inter_g = shamirs.shares(int(key), quantity= int(numero_shares), threshold=int(k))
print("Shares a compartir entre generaciones: \n")
print(sss_inter_g)

# Seleccionamos k-1 shares que se han de repartir en g1,
# los k-1 siguientes shares se reparten en g2 y asi sucesivamente.

start_p = 0
inicio_g = 0
end_p = int(k)-1
index_sss = 1
for i in range(numero_generaciones):
    print("Generacion " +  str( i + 1))
    print ("from " +  str(inicio_g) + "  " + str(generation_size(i + 1, int(k))) + " posiciones")
    print(participants[inicio_g:(inicio_g + generation_size(i + 1, int(k)))])
    participants_in_g = participants[inicio_g:(inicio_g + generation_size(i + 1, int(k)))]
    print("\n")
    shares_for_g = sss_inter_g[start_p:end_p]
    print("k -1 shares..." + str(shares_for_g))
    print("\n")

    # Hay que repartir cada share s_i entre los miembros de la generación g 
    # usando SSS(i, size(g))
    idx_threshold = 1
    for share in shares_for_g:
        
        sss_share_i = shamirs.shares(share.value, quantity = generation_size(i + 1, int(k)), threshold = idx_threshold)
        print("Shares para cada miembro de Generación " + str(i+1) + " " + " en el nivel " + str(idx_threshold) + " " + str(sss_share_i))
        print("\n")
                  
        # Falta guardar en cada participante su share en el nivel que le corresponda
        t = 0
        for participant in participants_in_g:
            print("Particpant")
            print("\n")
            print(participant)
            
            print("\n")
            print("threshold")
            print(idx_threshold)
            print("\n")

            print("Share")
            print("\n")
            sss_share_i[t].index = index_sss
            print(sss_share_i[t])
            globals()[participant].append(sss_share_i[t])
            t = t + 1
            
        idx_threshold = idx_threshold + 1
        index_sss = index_sss + 1

    start_p = end_p
    end_p = start_p + (int(k)-1)
    inicio_g = inicio_g + generation_size(i + 1, int(k))
# Out:
# Shares a compartir entre generaciones:
#
# [share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
# Generacion 1
# from 0  4 posiciones
# ['Pedro', 'Manuel', 'Maria', 'Luis']
#
#
# k -1 shares...[share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)]
#
#
# Shares para cada miembro de Generación 1  en el nivel 1 [share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(2, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(3, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(4, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727)]
#
#
# Particpant
#
#
# Pedro
#
#
# threshold
# 1
#
#
# Share
#
#
# share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727)
# Particpant
#
#
# Manuel
#
#
# threshold
# 1
#
#
# Share
#
#
# share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727)
# Particpant
#
#
# Maria
#
#
# threshold
# 1
#
#
# Share
#
#
# share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727)
# Particpant
#
#
# Luis
#
#
# threshold
# 1
#
#
# Share
#
#
# share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727)
# Shares para cada miembro de Generación 1  en el nivel 2 [share(1, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727), share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727), share(3, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727), share(4, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)]
#
#
# Particpant
#
#
# Pedro
#
#
# threshold
# 2
#
#
# Share
#
#
# share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)
# Particpant
#
#
# Manuel
#
#
# threshold
# 2
#
#
# Share
#
#
# share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)
# Particpant
#
#
# Maria
#
#
# threshold
# 2
#
#
# Share
#
#
# share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)
# Particpant
#
#
# Luis
#
#
# threshold
# 2
#
#
# Share
#
#
# share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)
# Generacion 2
# from 4  8 posiciones
# ['Ana', 'Rocio', 'Kevin', 'Jorge', 'Mario', 'Guillermo', 'Sara', 'Rebeca']
#
#
# k -1 shares...[share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
#
#
# Shares para cada miembro de Generación 2  en el nivel 1 [share(1, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(2, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(5, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(6, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(7, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(8, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)]
#
#
# Particpant
#
#
# Ana
#
#
# threshold
# 1
#
#
# Share
#
#
# share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)
# Particpant
#
#
# Rocio
#
#
# threshold
# 1
#
#
# Share
#
#
# share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)
# Particpant
#
#
# Kevin
#
#
# threshold
# 1
#
#
# Share
#
#
# share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)
# Particpant
#
#
# Jorge
#
#
# threshold
# 1
#
#
# Share
#
#
# share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)
# Particpant
#
#
# Mario
#
#
# threshold
# 1
#
#
# Share
#
#
# share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)
# Particpant
#
#
# Guillermo
#
#
# threshold
# 1
#
#
# Share
#
#
# share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)
# Particpant
#
#
# Sara
#
#
# threshold
# 1
#
#
# Share
#
#
# share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)
# Particpant
#
#
# Rebeca
#
#
# threshold
# 1
#
#
# Share
#
#
# share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)
# Shares para cada miembro de Generación 2  en el nivel 2 [share(1, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727), share(2, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727), share(3, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727), share(5, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727), share(6, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727), share(7, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727), share(8, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
#
#
# Particpant
#
#
# Ana
#
#
# threshold
# 2
#
#
# Share
#
#
# share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)
# Particpant
#
#
# Rocio
#
#
# threshold
# 2
#
#
# Share
#
#
# share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)
# Particpant
#
#
# Kevin
#
#
# threshold
# 2
#
#
# Share
#
#
# share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)
# Particpant
#
#
# Jorge
#
#
# threshold
# 2
#
#
# Share
#
#
# share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)
# Particpant
#
#
# Mario
#
#
# threshold
# 2
#
#
# Share
#
#
# share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)
# Particpant
#
#
# Guillermo
#
#
# threshold
# 2
#
#
# Share
#
#
# share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)
# Particpant
#
#
# Sara
#
#
# threshold
# 2
#
#
# Share
#
#
# share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)
# Particpant
#
#
# Rebeca
#
#
# threshold
# 2
#
#
# Share
#
#
# share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)

# %%
for participant in participants:
    print(participant)
    print(globals()[participant])
# Out:
# Pedro
# [share(1, 126389823754348948066896313035488939980, 170141183460469231731687303715884105727), share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)]
# Manuel
# [share(2, 82638464048228664402105322352951417998, 170141183460469231731687303715884105727), share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)]
# Maria
# [share(3, 38887104342108380737314331670413896016, 170141183460469231731687303715884105727), share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)]
# Luis
# [share(4, 165276928096457328804210644703760479761, 170141183460469231731687303715884105727), share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727)]
# Ana
# [share(1, 70301567886194670075071481416772557598, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
# Rocio
# [share(2, 140603135772389340150142962831402758961, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
# Kevin
# [share(3, 40763520198114778493527140530148854597, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
# Jorge
# [share(4, 111065088084309448568598621944779055960, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
# Mario
# [share(5, 11225472510034886911982799643525151596, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
# Guillermo
# [share(6, 81527040396229556987054281058155352959, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
# Sara
# [share(7, 151828608282424227062125762472785554322, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]
# Rebeca
# [share(8, 51988992708149665405509940171531649958, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727), share(4, 130087008935576461390254293464819411787, 170141183460469231731687303715884105727)]

# %%
def decrypt_diff_generations(lista_final):
    generaciones_decrypt = []
    for miembro in lista_final:
            generaciones_decrypt.append(participant_generation(miembro))
    print("Participants: \n")
    print(lista_final)
    print("Generations: \n")
    print(generaciones_decrypt)
    lista_shares = []
    gen_aux = []
    gen_idx = []
    
    for gen in generaciones_decrypt:
        if gen not in gen_aux:
            gen_aux.append(gen)
            gen_idx.append(1)
        else: 
            gen_count = gen_aux.count(gen)
            gen_aux.append(gen)
            gen_idx.append(gen_count + 1)
            
    print("Lista de ocurrencias por generación: \n")
    print(gen_idx)
    for miembro in lista_final:
        lista_shares.append(globals()[miembro][gen_idx[lista_final.index(miembro)]])
    print(lista_shares)
    print("Desencpritamos....\n")    
    desencriptado = shamirs.interpolate(lista_shares, threshold= int(k))
    
    return desencriptado

# %%
# Funcion Desencryptar

def desencripta(lista_desencryptar):
    if len(lista_desencryptar) < int(k):
        print("""El numero de partipantes para poder obtener la clava ha de ser mayor o igual \n
        al threshold k, cuyo valor actual es: """ + str(k))
    else:
        lista_final = lista_desencryptar[0:int(k)]
        generaciones_decrypt = []
        for miembro in lista_final:
            generaciones_decrypt.append(participant_generation(miembro))
        # Si todos los participantes para desencrptar pertenecen a la misma generación
        if all(element == generaciones_decrypt[0] for element in generaciones_decrypt):
            lista_shares = []
            print("Los candidatos son de la misma generación")
            for i in lista_final:
            
                #print(i)
                #print(locals()[i][0])
                lista_shares.append(globals()[i][0])

            #desencriptado= lista_shares
            desencriptado = shamirs.interpolate(lista_shares, threshold= int(k))
        else:
            # Si pertenecen a generaciones diferentes
            
            print("Los candidatos son de diferentes generaciones")
            decrypt_diff_generations
            desencriptado = decrypt_diff_generations(lista_final)
                
            
            

    return desencriptado

# %%
# ['Pedro', 'Manuel', 'Maria', 'Luis', 'Ana', 'Rocio', 'Kevin', 'Jorge', 'Mario', 'Guillermo', 'Sara', 'Rebeca']

# %%
lista_desencryptar = ["Pedro", "Manuel", "Sara"]

# %%
desencripta(lista_desencryptar)
# Out:
# Los candidatos son de diferentes generaciones
# Participants:
#
# ['Pedro', 'Manuel', 'Sara']
# Generations:
#
# [1, 1, 2]
# Lista de ocurrencias por generación:
#
# [1, 2, 1]
# [share(1, 32521752233894115347563573367811620123, 170141183460469231731687303715884105727), share(2, 65043504467788230695127146733480884011, 170141183460469231731687303715884105727), share(3, 97565256701682346042690720099150147899, 170141183460469231731687303715884105727)]
# Desencpritamos....
# 2142356235
